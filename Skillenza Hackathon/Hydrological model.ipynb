# %%
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv("bengaluru (1).csv")

# %%
df.head()
# Out:
#     date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  07-07-2020        26        21             0     12.9        6
# 1  08-07-2020        29        21             0     12.9        6
# 2  09-07-2020        27        22             0     10.5        6
# 3  10-07-2020        25        21             0      7.8        5
# 4  11-07-2020        26        21             0     12.5        5
#
#    moon_illumination  moonrise   moonset  sunrise  ... WindGustKmph  \
# 0                 85   8:53 PM   7:45 AM  5:59 AM  ...           26
# 1                 77   9:38 PM   8:39 AM  5:59 AM  ...           20
# 2                 70  10:19 PM   9:31 AM  6:00 AM  ...           24
# 3                 63  10:57 PM  10:19 AM  6:00 AM  ...           27
# 4                 55  11:34 PM  11:06 AM  6:00 AM  ...           24
#
#    cloudcover  humidity  precipMM  pressure  tempC  visibility  winddirDegree  \
# 0          44        72       0.7      1008     26          10            254
# 1          39        69       9.3      1008     29           9            258
# 2          62        74      24.1      1007     27           8            254
# 3          74        83      30.4      1007     25           8            260
# 4          54        77      13.1      1008     26           9            261
#
#    windspeedKmph   location
# 0             21  bengaluru
# 1             15  bengaluru
# 2             16  bengaluru
# 3             19  bengaluru
# 4             17  bengaluru
#
# [5 rows x 25 columns]

# %%
df['maxtempC'].plot(figsize=(12,5))
# Out:
# <AxesSubplot:>

# %%
df['mintempC'].plot(figsize=(12,5))
# Out:
# <AxesSubplot:>

# %%
df['totalSnow_cm'].plot(figsize=(12,5))
# Out:
# <AxesSubplot:>

# %%
df['sunHour'].plot(figsize=(12,5))
# Out:
# <AxesSubplot:>

# %%
plt.scatter('sunHour','totalSnow_cm')
plt.show()

# %%
df.info
# Out:
# <bound method DataFrame.info of       date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0    07-07-2020        26        21             0     12.9        6
# 1    08-07-2020        29        21             0     12.9        6
# 2    09-07-2020        27        22             0     10.5        6
# 3    10-07-2020        25        21             0      7.8        5
# 4    11-07-2020        26        21             0     12.5        5
# ..          ...       ...       ...           ...      ...      ...
# 360  02-07-2021        26        23             0     10.6        5
# 361  03-07-2021        24        21             0     11.9        5
# 362  04-07-2021        29        22             0     10.6        6
# 363  05-07-2021        28        23             0     12.9        6
# 364  06-07-2021        28        23             0     11.9        6
#
#      moon_illumination  moonrise   moonset  sunrise  ... WindGustKmph  \
# 0                   85   8:53 PM   7:45 AM  5:59 AM  ...           26
# 1                   77   9:38 PM   8:39 AM  5:59 AM  ...           20
# 2                   70  10:19 PM   9:31 AM  6:00 AM  ...           24
# 3                   63  10:57 PM  10:19 AM  6:00 AM  ...           27
# 4                   55  11:34 PM  11:06 AM  6:00 AM  ...           24
# ..                 ...       ...       ...      ...  ...          ...
# 360                 44  12:21 AM  12:42 PM  5:58 AM  ...           21
# 361                 36  12:57 AM   1:28 PM  5:58 AM  ...           18
# 362                 29   1:33 AM   2:14 PM  5:58 AM  ...           15
# 363                 22   2:10 AM   3:02 PM  5:58 AM  ...           16
# 364                 15   2:50 AM   3:51 PM  5:59 AM  ...           16
#
#      cloudcover  humidity  precipMM  pressure  tempC  visibility  \
# 0            44        72       0.7      1008     26          10
# 1            39        69       9.3      1008     29           9
# 2            62        74      24.1      1007     27           8
# 3            74        83      30.4      1007     25           8
# 4            54        77      13.1      1008     26           9
# ..          ...       ...       ...       ...    ...         ...
# 360          70        71      22.8      1008     26           9
# 361          57        77      21.4      1010     24           9
# 362          64        62       2.2      1009     29          10
# 363          63        63       3.3      1009     28          10
# 364          58        65       7.2      1007     28          10
#
#      winddirDegree  windspeedKmph   location
# 0              254             21  bengaluru
# 1              258             15  bengaluru
# 2              254             16  bengaluru
# 3              260             19  bengaluru
# 4              261             17  bengaluru
# ..             ...            ...        ...
# 360            271             13  bengaluru
# 361            265             12  bengaluru
# 362            276             11  bengaluru
# 363            290             13  bengaluru
# 364            311             12  bengaluru
#
# [365 rows x 25 columns]>

# %% [markdown]
# # Cleaning

# %%
df.isnull().sum()
# Out:
# date_time            0
# maxtempC             0
# mintempC             0
# totalSnow_cm         0
# sunHour              0
# uvIndex              0
# moon_illumination    0
# moonrise             0
# moonset              0
# sunrise              0
# sunset               0
# DewPointC            0
# FeelsLikeC           0
# HeatIndexC           0
# WindChillC           0
# WindGustKmph         0
# cloudcover           0
# humidity             0
# precipMM             0
# pressure             0
# tempC                0
# visibility           0
# winddirDegree        0
# windspeedKmph        0
# location             0
# dtype: int64

# %%
df.boxplot(figsize=(20,15))
plt.show()

# %%
correlation = df.corr()
sb.heatmap(correlation)
# Out:
# <AxesSubplot:>

# %%
sb.pairplot(df)

# %%
sb.scatterplot(x= 'pressure', y= 'humidity',hue= 'tempC', data=df)
# Out:
# <AxesSubplot:xlabel='pressure', ylabel='humidity'>

# %%
sb.scatterplot(x= 'precipMM', y= 'windspeedKmph',hue= 'cloudco', data=df)
